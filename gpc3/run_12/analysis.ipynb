# %% [markdown]
# # Analysis

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('out/boltzgen/2511011018/unfiltered/job_17/final_ranked_designs/final_designs_metrics_80.csv')
target_columns = [col for col in df.columns if "bindsite" in col.lower()]
df[target_columns].max()
# Out:
# bindsite_under_3rmsd    0.00000
# bindsite_under_4rmsd    0.16667
# bindsite_under_5rmsd    0.33333
# bindsite_under_6rmsd    0.66667
# bindsite_under_7rmsd    0.83333
# bindsite_under_8rmsd    1.00000
# bindsite_under_9rmsd    1.00000
# dtype: float64
