# %% [markdown]
# # PDB analysis

# %%
import numpy as numpy
import pandas as pd

# %%
from biotite.structure.io.pdb import PDBFile

# %%
x = PDBFile.read("design_0_dldesign_0_best.pdb",)

# %%
x.get_
