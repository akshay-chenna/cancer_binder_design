# %% [markdown]
# # Analysis of the top 5000 ranked designs

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('out/boltzgen/2511121535/combined/final_ranked_designs/final_designs_metrics_5000.csv')

# %%
target_columns = [col for col in df.columns if "bindsite" in col.lower()]

# %%
df[target_columns].max()
# Out:
# bindsite_under_3rmsd    0.00000
# bindsite_under_4rmsd    0.00000
# bindsite_under_5rmsd    0.07143
# bindsite_under_6rmsd    0.07143
# bindsite_under_7rmsd    0.07143
# bindsite_under_8rmsd    0.07143
# bindsite_under_9rmsd    0.14286
# dtype: float64
